# %% [markdown]
# <span style="color:orange">
#  <h2> Databricks-Assignment 3 (Basic String Manupulation Transformation)
# </span>
#   <h5>
#     <span style="color:orange">
# <b>Author: Gopinath <br>
#    <a>  </a><br>
#    Email at: gopinathma09@gmail.com
# </span>

# %% [markdown]
# <b> How many employees have a first name that starts with the letter 'J'?

# %%
from pyspark.sql.functions import *
df1=spark.read.csv("/FileStore/EmployeeData_HhTLiz9LdC.csv",header=True,inferSchema=True)
display(df1)
df2=df1.filter(df1.first_name.startswith('J'))
df2.count()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql.functions import *
#       2 df1=spark.read.csv("/FileStore/EmployeeData_HhTLiz9LdC.csv",header=True,inferSchema=True)
#       3 display(df1)
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
df100=df1.createOrReplaceTempView("Employee")
df101=spark.sql("Select * from Employee where first_name like 'J%'")
display(df101)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>first_name</th><th>last_name</th><th>email</th><th>gender</th><th>salary</th><th>creationDate</th><th>bonus</th></tr></thead><tbody><tr><td>16</td><td>Josee</td><td>Burnep</td><td>jburnepf@php.net</td><td>null</td><td>78569</td><td>1923-11-08T20:59:14.000+0000</td><td>88925.13</td></tr><tr><td>53</td><td>Jermaine</td><td>Clayborn</td><td>jclayborn1g@oakley.com</td><td>Female</td><td>20034</td><td>1901-06-02T00:16:24.000+0000</td><td>86427.24</td></tr><tr><td>null</td><td>Joe</td><td>Kilbee</td><td>jkilbee1w@dedecms.com</td><td>Male</td><td>147066</td><td>1912-10-21T01:47:26.000+0000</td><td>63886.43</td></tr><tr><td>78</td><td>Jillian</td><td>Chasmar</td><td>null</td><td>Female</td><td>18805</td><td>2019-01-07T02:06:41.000+0000</td><td>93412.65</td></tr><tr><td>98</td><td>Joella</td><td>Edmunds</td><td>jedmunds2p@dropbox.com</td><td>Female</td><td>49283</td><td>1994-06-09T17:34:15.000+0000</td><td>94776.88</td></tr><tr><td>153</td><td>Jozef</td><td>Drewes</td><td>jdrewes48@wikispaces.com</td><td>Male</td><td>16803</td><td>1949-04-30T12:53:34.000+0000</td><td>54789.31</td></tr><tr><td>163</td><td>Jeffrey</td><td>Sugars</td><td>null</td><td>Male</td><td>112937</td><td>1978-08-15T19:03:34.000+0000</td><td>92001.92</td></tr><tr><td>169</td><td>Jamesy</td><td>Gilby</td><td>null</td><td>Male</td><td>153493</td><td>1971-01-28T04:00:18.000+0000</td><td>27030.09</td></tr><tr><td>185</td><td>Jocko</td><td>Boyington</td><td>jboyington54@chron.com</td><td>Male</td><td>112842</td><td>null</td><td>21712.37</td></tr><tr><td>196</td><td>Jeanne</td><td>Rearie</td><td>jrearie5f@marriott.com</td><td>Female</td><td>104483</td><td>2011-04-16T15:51:52.000+0000</td><td>null</td></tr><tr><td>202</td><td>Junia</td><td>Petrovsky</td><td>jpetrovsky5l@cdc.gov</td><td>Female</td><td>76268</td><td>1993-10-02T03:32:57.000+0000</td><td>12547.89</td></tr><tr><td>279</td><td>Joeann</td><td>Stenner</td><td>jstenner7q@google.cn</td><td>Female</td><td>61864</td><td>1939-05-18T16:17:25.000+0000</
:19.000+0000</td><td>83648.95</td></tr><tr><td>252</td><td>Burch</td><td>Hargess</td><td>bhargess6z@shop-pro.jp</td><td>Male</td><td>194091</td><td>1914-11-04T08:39:08.000+0000</td><td>83395.4</td></tr><tr><td>261</td><td>Maurine</td><td>Isaacs</td><td>misaacs78@cafepress.com</td><td>Female</td><td>11142</td><td>1954-07-23T14:19:27.000+0000</td><td>76999.9</td></tr><tr><td>269</td><td>Charlot</td><td>Rawlins</td><td>crawlins7g@vinaora.com</td><td>Female</td>< ...

# %% [markdown]
# <b> What is the length of the longest first name?

# %%
df4=df1.withColumn("len_longest_fist_name",length(df1.first_name)).groupBy().max("len_longest_fist_name")
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max(len_longest_fist_name)</th></tr></thead><tbody><tr><td>15</td></tr></tbody></table></div>

# %%
df103=spark.sql("Select len(first_name) as len_longest_fist_name from Employee order by len_longest_fist_name DESC limit 1")
display(df103)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>len_longest_fist_name</th></tr></thead><tbody><tr><td>15</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> What is the length of the shortest last name?

# %%
df5=df1.withColumn("len_shortest_last_name",length(df1.last_name)).groupBy().min("len_shortest_last_name")
display(df5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min(len_shortest_last_name)</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
df104=spark.sql("Select len(last_name) as len_shortest_last_name from Employee where last_name is not NULL order by len_shortest_last_name  limit 1")
display(df104)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>len_shortest_last_name</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b>What is the email domain of the employee with the highest salary?

# %%
highest_salary_email_dom=df1.select(split("email","@").getItem(1).alias("email_domain"),"salary").orderBy(desc("salary")).limit(1).select("email_domain").collect()[0][0]
display(highest_salary_email_dom)
# Out:
# 'webs.com'

# %%
df110=spark.sql("select substring(email,CHARINDEX( '@', email) +1,LEN(email)) as email_domain from Employee where salary not in ('null') order by salary desc limit 1 ")
display(df110)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email_domain</th></tr></thead><tbody><tr><td>webs.com</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> What is the first name of the employee with the email address that contains the substring 'hr'?

# %%
df7=df1.filter(df1.email.contains('hr')).select("first_name",'email').show()

# %%
df105=spark.sql("select first_name,email from Employee where email like '%hr%'")
display(df105)

# %% [markdown]
# d
# <b> What is the last name of the employee with the email address that ends with the domain '.com'?

# %%
df7=df1.filter(df1.email.endswith('.com')).select("last_name","email")
display(df7)

# %%
df106=spark.sql("Select last_name,email from Employee where email like '%.com'")
display(df106)

# %% [markdown]
# d
# <b> How many employees have an email address that contains their last name?

# %%
df8=df1.filter(df1.email.contains(lower(df1.last_name))).show()

# %%
df107=spark.sql("Select * from Employee where email like last_name")
display(df107)

# %% [markdown]
# d
# <b> What is the email of the employee with the first name that contains a space character?

# %%
df9=df1.filter(df1.first_name.like("% %")).select("first_name","email")
display(df9)

# %%
df108=spark.sql("Select first_name,email from Employee where first_name like '% %'")
display(df108)

# %% [markdown]
# d
# <b> What is the email of the employee with the last name that contains a hyphen character?

# %%
df10=df1.filter(df1.last_name.contains('-')).select("last_name",'email')
display(df10)

# %%
df109=spark.sql("select last_name,email from employee where last_name like '%-%'")
display(df109)
